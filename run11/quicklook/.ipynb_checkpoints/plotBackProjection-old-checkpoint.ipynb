# %%
import numpy as np
import matplotlib.pyplot as plt
import uproot

plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams["font.size"] = 15
plt.rcParams['xtick.labelsize'] = 13
plt.rcParams['ytick.labelsize'] = 13

# %%
def plotBackProjection(filePath, num_points, title=None):
    file = uproot.open(f"{filePath}")
    projection = file["BackProjection/h_bp_all"]
    countsArray, binsArrayX, binsArrayY = projection.to_numpy()
    
    threshold = 0.5 / num_points
    H_masked = np.ma.masked_less(countsArray.T, threshold)

    fig, ax = plt.subplots(1,1,figsize=(6,5))
    cmap = plt.cm.viridis.copy()
    cmap.set_bad("white")
    pcm = ax.pcolormesh(binsArrayX, binsArrayY, H_masked, cmap=cmap, vmin=0)
    cbar = fig.colorbar(pcm, ax=ax)
    cbar.set_label("Counts")
    ax.set_xlim(binsArrayX[0], binsArrayX[-1])
    ax.set_ylim(binsArrayY[0], binsArrayY[-1])
    ax.set_xlabel("Y (cm)")
    ax.set_ylabel("Z (cm)")
    ax.set_aspect("equal")
    if title != None:
        ax.set_title(title)

# %%
data_info_dict = {"Na22": r"$^{22}\mathrm{Na}$"}

for data_type, title in data_info_dict.items():
    filePath = f"../products/{data_type}/compton_image.root"
    plotBackProjection(filePath, num_points=10000, title=title)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 5
#       1 data_info_dict = {"Na22": r"$^{22}\mathrm{Na}$"}
#       2
#       3 for data_type, title in data_info_dict.items():
#       4     filePath = f"../products/{data_type}/compton_image.root"
# ----> 5     plotBackProjection(filePath, num_points=10000, title=title)
#
# Cell In[2], line 2, in plotBackProjection(filePath, num_points, title)
#       1 def plotBackProjection(filePath, num_points, title=None):
# ----> 2     file = uproot.open(f"{filePath}")
#       3     projection = file["BackProjection/h_bp_all"]
#       4     countsArray, binsArrayX, binsArrayY = projection.to_numpy()
#       5
#
# File ~/.pyenv/versions/3.12.12/lib/python3.12/site-packages/uproot/reading.py:144, in open(path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     135 if not isinstance(file_path, str) and not (
#     136     hasattr(file_path, "read") and hasattr(file_path, "seek")
#     137 ):
#     138     raise ValueError(
#     139         "'path' must be a string, pathlib.Path, an object with 'read' and "
#     140         "'seek' methods, or a length-1 dict of {file_path: object_path}, "
#     141         f"not {path!r}"
#     142     )
# --> 144 file = ReadOnlyFile(
#     145     file_path,
#     146     object_cache=object_cache,
#     147     array_cache=array_cache,
#     148     custom_classes=custom_classes,
#     149     decompression_executor=decompression_executor,
#     150     interpretation_executor=interpretation_executor,
#     151     **options,
#     152 )
#     154 if object_path is None:
#     155     return file.root_directory
#
# File ~/.pyenv/versions/3.12.12/lib/python3.12/site-packages/uproot/reading.py:563, in ReadOnlyFile.__init__(self, file_path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     558 self.hook_before_create_source()
#     560 source_cls, file_path = uproot._util.file_path_to_source_class(
#     561     file_path, self._options
#     562 )
# --> 563 self._source = source_cls(file_path, **self._options)
#     565 self.hook_before_get_chunks()
#     567 if self._options["begin_chunk_size"] < _file_header_fields_big.size:
#
# File ~/.pyenv/versions/3.12.12/lib/python3.12/site-packages/uproot/source/fsspec.py:63, in FSSpecSource.__init__(self, file_path, coalesce_config, **options)
#      59 self._fsspec_options = {
#      60     k: v for k, v in options.items() if k not in uproot.reading.open.defaults
#      61 }
#      62 self._file_path_orig = file_path
# ---> 63 self._open()
#
# File ~/.pyenv/versions/3.12.12/lib/python3.12/site-packages/uproot/source/fsspec.py:70, in FSSpecSource._open(self)
#      68 self._fs = self._open_file.fs
#      69 self._file_path = self._open_file.path
# ---> 70 self._fo = self._open_file.__enter__()
#      71 self._async_impl = self._fs.async_impl
#      72 self._closed = False
#
# File ~/.pyenv/versions/3.12.12/lib/python3.12/site-packages/fsspec/core.py:105, in OpenFile.__enter__(self)
#     102 mode = self.mode.replace("t", "").replace("b", "") + "b"
#     104 try:
# --> 105     f = self.fs.open(self.path, mode=mode)
#     106 except FileNotFoundError as e:
#     107     if has_magic(self.path):
#
# File ~/.pyenv/versions/3.12.12/lib/python3.12/site-packages/fsspec/spec.py:1352, in AbstractFileSystem.open(self, path, mode, block_size, cache_options, compression, **kwargs)
#    1350 else:
#    1351     ac = kwargs.pop("autocommit", not self._intrans)
# -> 1352     f = self._open(
#    1353         path,
#    1354         mode=mode,
#    1355         block_size=block_size,
#    1356         autocommit=ac,
#    1357         cache_options=cache_options,
#    1358         **kwargs,
#    1359     )
#    1360     if compression is not None:
#    1361         from fsspec.compression import compr
#
# File ~/.pyenv/versions/3.12.12/lib/python3.12/site-packages/fsspec/implementations/local.py:215, in LocalFileSystem._open(self, path, mode, block_size, **kwargs)
#     213 if self.auto_mkdir and "w" in mode:
#     214     self.makedirs(self._parent(path), exist_ok=True)
# --> 215 return LocalFileOpener(path, mode, fs=self, **kwargs)
#
# File ~/.pyenv/versions/3.12.12/lib/python3.12/site-packages/fsspec/implementations/local.py:390, in LocalFileOpener.__init__(self, path, mode, autocommit, fs, compression, **kwargs)
#     388 self.compression = get_compression(path, compression)
#     389 self.blocksize = io.DEFAULT_BUFFER_SIZE
# --> 390 self._open()
#
# File ~/.pyenv/versions/3.12.12/lib/python3.12/site-packages/fsspec/implementations/local.py:395, in LocalFileOpener._open(self)
#     393 if self.f is None or self.f.closed:
#     394     if self.autocommit or "w" not in self.mode:
# --> 395         self.f = open(self.path, mode=self.mode)
#     396         if self.compression:
#     397             compress = compr[self.compression]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/takashima/work/grams/nanograms-analysis/run11/quicklook/../products/Na22/compton_image.root'
